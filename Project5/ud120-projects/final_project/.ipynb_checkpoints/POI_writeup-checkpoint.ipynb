# %% [markdown]
# # Finding Enron persons of interest from email and financial data

# %%
# standard library imports
import pickle
import sys
sys.path.append("../tools/")

# package imports
from ggplot import *
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier
from sklearn.feature_selection import RFE
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.preprocessing import scale, StandardScaler
from sklearn.tree import DecisionTreeClassifier

# project imports
from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

# %%
# load date and transform to dataframe 
with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

# As soon as you print the data frame you see the'Total' 
# row is present from the spreadsheet and needs removed
data_dict.pop('TOTAL',0)

df = pd.DataFrame.from_dict(data_dict, orient = 'index')

# %% [markdown]
# ## Understanding the Dataset and Question

# %%
print "In our dataset we have"
print 'Observations(Enron employees): %s' % df.shape[0]
print 'Features: %s' % df.shape[1]
poi_count = sum(df['poi'])
poi_percent = round(poi_count/float(df.shape[0]),4) * 100
print "With %s of them (%s%%) being persons of interest" % (poi_count, poi_percent)
# Out:
# In our dataset we have
# Observations(Enron employees): 145
# Features: 21
# With 18 of them (12.41%) being persons of interest

# %% [markdown]
# When we preview our dataset, it looks like there will be a lot of data missing throughout it:

# %%
df.head()
# Out:
#                     salary to_messages deferral_payments total_payments  \
# ALLEN PHILLIP K     201955        2902           2869717        4484442
# BADUM JAMES P          NaN         NaN            178980         182466
# BANNANTINE JAMES M     477         566               NaN         916197
# BAXTER JOHN C       267102         NaN           1295738        5634343
# BAY FRANKLIN R      239671         NaN            260455         827696
#
#                    exercised_stock_options    bonus restricted_stock  \
# ALLEN PHILLIP K                    1729541  4175000           126027
# BADUM JAMES P                       257817      NaN              NaN
# BANNANTINE JAMES M                 4046157      NaN          1757552
# BAXTER JOHN C                      6680544  1200000          3942714
# BAY FRANKLIN R                         NaN   400000           145796
#
#                    shared_receipt_with_poi restricted_stock_deferred  \
# ALLEN PHILLIP K                       1407                   -126027
# BADUM JAMES P                          NaN                       NaN
# BANNANTINE JAMES M                     465                   -560222
# BAXTER JOHN C                          NaN                       NaN
# BAY FRANKLIN R                         NaN                    -82782
#
#                    total_stock_value           ...           loan_advances  \
# ALLEN PHILLIP K              1729541           ...                     NaN
# BADUM JAMES P                 257817           ...                     NaN
# BANNANTINE JAMES M           5243487           ...                     NaN
# BAXTER JOHN C               10623258           ...                     NaN
# BAY FRANKLIN R                 63014           ...                     NaN
#
#                    from_messages    other from_this_person_to_poi    poi  \
# ALLEN PHILLIP K             2195      152                      65  False
# BADUM JAMES P                NaN      NaN                     NaN  False
# BANNANTINE JAMES M            29   864523                       0  False
# BAXTER JOHN C                NaN  2660303                     NaN  False
# BAY FRANKLIN R               NaN       69                     NaN  False
#
#                    director_fees deferred_income long_term_incentive  \
# ALLEN PHILLIP K              NaN        -3081055              304805
# BADUM JAMES P                NaN             NaN                 NaN
# BANNANTINE JAMES M           NaN           -5104                 NaN
# BAXTER JOHN C                NaN        -1386055             1586055
# BAY FRANKLIN R               NaN         -201641                 NaN
#
#                                  email_address from_poi_to_this_person
# ALLEN PHILLIP K        phillip.allen@enron.com                      47
# BADUM JAMES P                              NaN                     NaN
# BANNANTINE JAMES M  james.bannantine@enron.com                      39
# BAXTER JOHN C                              NaN                     NaN
# BAY FRANKLIN R             frank.bay@enron.com                     NaN
#
# [5 rows x 21 columns]

# %% [markdown]
#  Let's get a handle on how many missing observations there are for each column:

# %%
def percent_missing(df, cutoff_percent = 0.):
    for col in df.columns:
        try:
            missing_percent = sum(df[col] == 'NaN')/float(df.shape[0])
            if missing_percent >= cutoff_percent:
                print col, round(missing_percent, 2)
        except:
            # This is just poi bool
            pass

percent_missing(df)
# Out:
# salary 0.35
# to_messages 0.41
# deferral_payments 0.74
# total_payments 0.14
# exercised_stock_options 0.3
# bonus 0.44
# restricted_stock 0.25
# shared_receipt_with_poi 0.41
# restricted_stock_deferred 0.88
# total_stock_value 0.14
# expenses 0.35
# loan_advances 0.98
# from_messages 0.41
# other 0.37
# from_this_person_to_poi 0.41
# director_fees 0.89
# deferred_income 0.67
# long_term_incentive 0.55
# email_address 0.23
# from_poi_to_this_person 0.41
# /Users/scottbrenstuhl/Projects/Data_Analyst_Nanodegree/venv/lib/python2.7/site-packages/pandas/core/ops.py:716: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)

# %% [markdown]
# So it looks like we are missing some values in every field we have (besides poi which is not listed here) but we kind of expected as much with messy data. Let's focus on the most worysome ones.

# %%
percent_missing(df, .5)
# Out:
# deferral_payments 0.74
# restricted_stock_deferred 0.88
# loan_advances 0.98
# director_fees 0.89
# deferred_income 0.67
# long_term_incentive 0.55

# %% [markdown]
# With these values missing in over half of observations, we will want to be especially cautious about how we use them. Althrough since we are hunting for very specific people that only make up 12% of the observations, it is possible some of them could be very useful.
#
# With loan_advances only appearing in 2% I'll be removing it.

# %%
df = df.drop('loan_advances',axis=1)

# %%
# Create a version of the dataframe with missing values filled in
df_filled = df.replace('NaN',0)
df_filled['email_address'] = df_filled['email_address'].replace(0, 'None')

# %% [markdown]
# Outliers are going to be tricky with this data set. I wanted to find the most agredious outliers but with so much missing data as 0s and the insanely high financial benifits some of these people were recieving, I had to go all the way up to features that have a max value seven standard deviations above the mean to focus on half the features.
#
# It looks like most of the features with big outliers are compensation items besides normal salary and bonuses. This kind of makes sense though with there be hevily compensated execs and normal employees so we don't know that any of these are actually problematic and will have to look into them more individually.

# %%
# setting to not use scientific notation since that made this harder to read
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df_description = df_filled.describe()

largest_outliers = [x for x in df_description if 
                    df_description[x]['max'] > df_description[x]['mean'] + df_description[x]['std'] * 7]

df_description[largest_outliers]
# Out:
#        deferral_payments  total_payments  restricted_stock_deferred  \
# count            145.000         145.000                    145.000
# mean          220557.903     2243477.421                  72911.572
# std           751704.629     8817819.452                1297469.064
# min          -102500.000           0.000               -1787380.000
# 25%                0.000       91093.000                      0.000
# 50%                0.000      916197.000                      0.000
# 75%             7961.000     1934359.000                      0.000
# max          6426990.000   103559793.000               15456290.000
#
#        total_stock_value  from_messages        other  from_this_person_to_poi  \
# count            145.000        145.000      145.000                  145.000
# mean         2889718.124        361.076   295210.021                   24.455
# std          6172223.036       1445.945  1127404.270                   79.527
# min           -44093.000          0.000        0.000                    0.000
# 25%           221141.000          0.000        0.000                    0.000
# 50%           955873.000         17.000      947.000                    0.000
# 75%          2282768.000         52.000   150458.000                   14.000
# max         49110078.000      14368.000 10359729.000                  609.000
#
#        long_term_incentive
# count              145.000
# mean            334633.986
# std             685363.856
# min                  0.000
# 25%                  0.000
# 50%                  0.000
# 75%             374347.000
# max            5145434.000

# %%
for col in df_description:
    print ggplot(aes('poi', col), data = df_filled) +\
            geom_boxplot()
# Out:
# <ggplot: (290104521)>
# <ggplot: (290249293)>
# <ggplot: (290681717)>
# <ggplot: (290681709)>
# <ggplot: (290681717)>
# <ggplot: (291789689)>
# <ggplot: (290663001)>
# <ggplot: (290663009)>
# <ggplot: (291776397)>
# <ggplot: (290599761)>
# <ggplot: (290599761)>
# <ggplot: (290657373)>
# <ggplot: (290599761)>
# <ggplot: (290657373)>
# <ggplot: (290599761)>
# <ggplot: (290657373)>
# <ggplot: (293565261)>
# <ggplot: (293300413)>

# %% [markdown]
# I looked through the box-plots of the features with the largest outliers and made a list of those where the outlier seems especially far away which might be problematic. It turns out though that most of them are Kenneth Lay whom we know made out like a bandit from the fraud so for now I will be leaving all the outliers alone.

# %%
aggressive_outliers = ['total_payments', 'restricted_stock', 
                        'shared_receipt_with_poi', 'restricted_stock_deferred',
                        'other']
outlier_list = []
for outlier in aggressive_outliers:
    outlier_row = df_filled[df_filled[outlier] == max(df_filled[outlier])]
    outlier_list.append({'feature' : outlier, 'person' : outlier_row.index.values[0], 'poi': outlier_row['poi'][0]})

pd.DataFrame(outlier_list)
# Out:
#                      feature            person    poi
# 0             total_payments     LAY KENNETH L   True
# 1           restricted_stock     LAY KENNETH L   True
# 2    shared_receipt_with_poi  BELDEN TIMOTHY N   True
# 3  restricted_stock_deferred  BHATNAGAR SANJAY  False
# 4                      other     LAY KENNETH L   True

# %% [markdown]
# ## Optimize Feature Selection/Engineering

# %% [markdown]
# People that recieve a director fee seem to be different from regular company employees, they don't draw a salary or bonuses and instead are compensated in stocks and director fees. I would like to see if using director as a boolian is more informative that specific values.

# %%
df['director'] = df['director_fees'] != 'NaN'
df[df['director_fees'] != 'NaN']
# Out:
#                         salary to_messages deferral_payments total_payments  \
# BELFER ROBERT              NaN         NaN           -102500         102500
# BHATNAGAR SANJAY           NaN         523               NaN       15456290
# BLAKE JR. NORMAN P         NaN         NaN               NaN           1279
# CHAN RONNIE                NaN         NaN               NaN            NaN
# DUNCAN JOHN H              NaN         NaN               NaN          77492
# GRAMM WENDY L              NaN         NaN               NaN         119292
# JAEDICKE ROBERT            NaN         NaN               NaN          83750
# LEMAISTRE CHARLES          NaN         NaN               NaN          87492
# MENDELSOHN JOHN            NaN         NaN               NaN            148
# MEYER JEROME J             NaN         NaN               NaN           2151
# PEREIRA PAULO V. FERRAZ    NaN         NaN               NaN          27942
# POWERS WILLIAM             NaN         653               NaN            NaN
# SAVAGE FRANK               NaN         NaN               NaN           3750
# URQUHART JOHN A            NaN         NaN               NaN         228656
# WAKEHAM JOHN               NaN         NaN               NaN         213071
# WINOKUR JR. HERBERT S      NaN         NaN               NaN          84992
#
#                         exercised_stock_options bonus restricted_stock  \
# BELFER ROBERT                              3285   NaN              NaN
# BHATNAGAR SANJAY                        2604490   NaN         -2604490
# BLAKE JR. NORMAN P                          NaN   NaN              NaN
# CHAN RONNIE                                 NaN   NaN            32460
# DUNCAN JOHN H                            371750   NaN              NaN
# GRAMM WENDY L                               NaN   NaN              NaN
# JAEDICKE ROBERT                          431750   NaN            44093
# LEMAISTRE CHARLES                        412878   NaN              NaN
# MENDELSOHN JOHN                             NaN   NaN              NaN
# MEYER JEROME J                              NaN   NaN              NaN
# PEREIRA PAULO V. FERRAZ                     NaN   NaN              NaN
# POWERS WILLIAM                              NaN   NaN              NaN
# SAVAGE FRANK                                NaN   NaN              NaN
# URQUHART JOHN A                             NaN   NaN              NaN
# WAKEHAM JOHN                                NaN   NaN              NaN
# WINOKUR JR. HERBERT S                       NaN   NaN              NaN
#
#                         shared_receipt_with_poi restricted_stock_deferred  \
# BELFER ROBERT                               NaN                     44093
# BHATNAGAR SANJAY                            463                  15456290
# BLAKE JR. NORMAN P                          NaN                       NaN
# CHAN RONNIE                                 NaN                    -32460
# DUNCAN JOHN H                               NaN                       NaN
# GRAMM WENDY L                               NaN                       NaN
# JAEDICKE ROBERT                             NaN                    -44093
# LEMAISTRE CHARLES                           NaN                       NaN
# MENDELSOHN JOHN                             NaN                       NaN
# MEYER JEROME J                              NaN                       NaN
# PEREIRA PAULO V. FERRAZ                     NaN                       NaN
# POWERS WILLIAM                               12                       NaN
# SAVAGE FRANK                                NaN                       NaN
# URQUHART JOHN A                             NaN                       NaN
# WAKEHAM JOHN                                NaN                       NaN
# WINOKUR JR. HERBERT S                       NaN                       NaN
#
#                         total_stock_value   ...    from_messages   other  \
# BELFER ROBERT                      -44093   ...              NaN     NaN
# BHATNAGAR SANJAY                      NaN   ...               29  137864
# BLAKE JR. NORMAN P                    NaN   ...              NaN     NaN
# CHAN RONNIE                           NaN   ...              NaN     NaN
# DUNCAN JOHN H                      371750   ...              NaN     NaN
# GRAMM WENDY L                         NaN   ...              NaN     NaN
# JAEDICKE ROBERT                    431750   ...              NaN     NaN
# LEMAISTRE CHARLES                  412878   ...              NaN     NaN
# MENDELSOHN JOHN                       NaN   ...              NaN     NaN
# MEYER JEROME J                        NaN   ...              NaN     NaN
# PEREIRA PAULO V. FERRAZ               NaN   ...              NaN     NaN
# POWERS WILLIAM                        NaN   ...               26     NaN
# SAVAGE FRANK                          NaN   ...              NaN     NaN
# URQUHART JOHN A                       NaN   ...              NaN     NaN
# WAKEHAM JOHN                          NaN   ...              NaN     NaN
# WINOKUR JR. HERBERT S                 NaN   ...              NaN     NaN
#
#                         from_this_person_to_poi    poi director_fees  \
# BELFER ROBERT                               NaN  False          3285
# BHATNAGAR SANJAY                              1  False        137864
# BLAKE JR. NORMAN P                          NaN  False        113784
# CHAN RONNIE                                 NaN  False         98784
# DUNCAN JOHN H                               NaN  False        102492
# GRAMM WENDY L                               NaN  False        119292
# JAEDICKE ROBERT                             NaN  False        108750
# LEMAISTRE CHARLES                           NaN  False        112492
# MENDELSOHN JOHN                             NaN  False        103750
# MEYER JEROME J                              NaN  False         38346
# PEREIRA PAULO V. FERRAZ                     NaN  False        101250
# POWERS WILLIAM                                0  False         17500
# SAVAGE FRANK                                NaN  False        125034
# URQUHART JOHN A                             NaN  False         36666
# WAKEHAM JOHN                                NaN  False        109298
# WINOKUR JR. HERBERT S                       NaN  False        108579
#
#                         deferred_income long_term_incentive  \
# BELFER ROBERT                       NaN                 NaN
# BHATNAGAR SANJAY                    NaN                 NaN
# BLAKE JR. NORMAN P              -113784                 NaN
# CHAN RONNIE                      -98784                 NaN
# DUNCAN JOHN H                    -25000                 NaN
# GRAMM WENDY L                       NaN                 NaN
# JAEDICKE ROBERT                  -25000                 NaN
# LEMAISTRE CHARLES                -25000                 NaN
# MENDELSOHN JOHN                 -103750                 NaN
# MEYER JEROME J                   -38346                 NaN
# PEREIRA PAULO V. FERRAZ         -101250                 NaN
# POWERS WILLIAM                   -17500                 NaN
# SAVAGE FRANK                    -121284                 NaN
# URQUHART JOHN A                  -36666                 NaN
# WAKEHAM JOHN                        NaN                 NaN
# WINOKUR JR. HERBERT S            -25000                 NaN
#
#                                       email_address from_poi_to_this_person  \
# BELFER ROBERT                                   NaN                     NaN
# BHATNAGAR SANJAY         sanjay.bhatnagar@enron.com                       0
# BLAKE JR. NORMAN P                              NaN                     NaN
# CHAN RONNIE                                     NaN                     NaN
# DUNCAN JOHN H                                   NaN                     NaN
# GRAMM WENDY L                                   NaN                     NaN
# JAEDICKE ROBERT                                 NaN                     NaN
# LEMAISTRE CHARLES                               NaN                     NaN
# MENDELSOHN JOHN                                 NaN                     NaN
# MEYER JEROME J                                  NaN                     NaN
# PEREIRA PAULO V. FERRAZ                         NaN                     NaN
# POWERS WILLIAM                 ken.powers@enron.com                       0
# SAVAGE FRANK                                    NaN                     NaN
# URQUHART JOHN A                                 NaN                     NaN
# WAKEHAM JOHN                                    NaN                     NaN
# WINOKUR JR. HERBERT S                           NaN                     NaN
#
#                         director
# BELFER ROBERT               True
# BHATNAGAR SANJAY            True
# BLAKE JR. NORMAN P          True
# CHAN RONNIE                 True
# DUNCAN JOHN H               True
# GRAMM WENDY L               True
# JAEDICKE ROBERT             True
# LEMAISTRE CHARLES           True
# MENDELSOHN JOHN             True
# MEYER JEROME J              True
# PEREIRA PAULO V. FERRAZ     True
# POWERS WILLIAM              True
# SAVAGE FRANK                True
# URQUHART JOHN A             True
# WAKEHAM JOHN                True
# WINOKUR JR. HERBERT S       True
#
# [16 rows x 21 columns]

# %% [markdown]
# I am also making features of what percent of emails were to/from pois instead of the straight counts that we have in the data set.

# %%
def email_percents(poi_emails, all_emails):
    percent_emails_to_poi = []
    for from_poi, all_from in zip(df[poi_emails], df[all_emails]):
        try:
            perc_to_poi = float(from_poi)/all_from
            percent_emails_to_poi.append(round(perc_to_poi,4))
        except:
            percent_emails_to_poi.append('NaN')
    return percent_emails_to_poi

df['percent_from_emails_to_poi'] = email_percents('from_this_person_to_poi', 'from_messages')
df['percent_emails_from_poi'] = email_percents('from_poi_to_this_person', 'to_messages')

# %% [markdown]
# From the plots below, it looks like the percents will be a more helpful parameter since it at least gives us some decent sized areas with only non pois.

# %%
ggplot(aes(x = 'from_this_person_to_poi', y = 'from_poi_to_this_person',
           color = 'poi' ), data = df ) +\
    geom_point() +\
    labs(title = "Count of emails to/from poi")
# Out:
# <ggplot: (293548205)>

# %%
ggplot(aes(x = 'percent_from_emails_to_poi', y = 'percent_emails_from_poi',
           color = 'poi' ), data = df ) +\
    geom_point()+\
    labs(title = "Percent of emails to/from poi")
# Out:
# <ggplot: (293532901)>

# %% [markdown]
# I was initially concerned about the person who sent 100% of their emails to a poi, but Gene Humphrey seems to be accurate, so we won't toss it as an outlier.

# %%
df[df['percent_from_emails_to_poi']==1][
    ['from_this_person_to_poi', 'from_messages', 'percent_from_emails_to_poi']]
# Out:
#                 from_this_person_to_poi from_messages  \
# HUMPHREY GENE E                      17            17
#
#                 percent_from_emails_to_poi
# HUMPHREY GENE E                      1.000

# %% [markdown]
# Now that we have created our new features lets split the test and training set.

# %%
# Split poi from the features
labels = df_filled['poi']
# I have relized I am not doing anything interesting with email addresses and they cause type issues
features = df_filled.drop(['poi', 'email_address'], axis=1)

features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels, test_size=0.25, random_state=1809)

# %% [markdown]
# I am really interested in learning about feature selection and seeing what different results we get from different
# strategies. I started with feature importance from random forest.

# %%
dt_clf = DecisionTreeClassifier(random_state=1809)
dt_clf.fit(features_train, labels_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1809, splitter='best')

# %% [markdown]
# It looks like a LOT of our features are useless, but we can see that 3 features are really useful for this approach and the importance plateaus around the 5th or 6th most important feature.

# %%
importance_df = pd.DataFrame({'features':features_train.columns, 'importance':dt_clf.feature_importances_})
dt_important_features = importance_df.sort_values('importance', ascending= False)['features'][0:6]
importance_df.sort_values('importance', ascending= False)
# Out:
#                       features  importance
# 15             deferred_income       0.257
# 19  percent_from_emails_to_poi       0.220
# 11               from_messages       0.197
# 12                       other       0.086
# 13     from_this_person_to_poi       0.073
# 16         long_term_incentive       0.058
# 4      exercised_stock_options       0.044
# 10                    expenses       0.039
# 9            total_stock_value       0.026
# 18                    director       0.000
# 17     from_poi_to_this_person       0.000
# 14               director_fees       0.000
# 0                       salary       0.000
# 1                  to_messages       0.000
# 8    restricted_stock_deferred       0.000
# 7      shared_receipt_with_poi       0.000
# 6             restricted_stock       0.000
# 5                        bonus       0.000
# 3               total_payments       0.000
# 2            deferral_payments       0.000
# 20     percent_emails_from_poi       0.000

# %%
scaler = StandardScaler().fit(features_train)
scaled_features_train = scaler.transform(features_train)
scaled_features_test = scaler.transform(features_test)

model = LogisticRegression()
rfe = RFE(model, 5)
rfe.fit(scaled_features_train, labels_train)

rfe_selected = features_train.columns[rfe.support_]

# Checking the order is consistant for my own sanity
if (rfe.support_ == [x in rfe_selected for x in importance_df['features'].values]).all():
    importance_df['rfe_selected'] = rfe.support_

importance_df.sort_values('importance', ascending= False)
# Out:
#                       features  importance rfe_selected
# 15             deferred_income       0.257         True
# 19  percent_from_emails_to_poi       0.220         True
# 11               from_messages       0.197        False
# 12                       other       0.086        False
# 13     from_this_person_to_poi       0.073         True
# 16         long_term_incentive       0.058        False
# 4      exercised_stock_options       0.044        False
# 10                    expenses       0.039        False
# 9            total_stock_value       0.026        False
# 18                    director       0.000        False
# 17     from_poi_to_this_person       0.000        False
# 14               director_fees       0.000        False
# 0                       salary       0.000        False
# 1                  to_messages       0.000        False
# 8    restricted_stock_deferred       0.000        False
# 7      shared_receipt_with_poi       0.000        False
# 6             restricted_stock       0.000        False
# 5                        bonus       0.000         True
# 3               total_payments       0.000        False
# 2            deferral_payments       0.000         True
# 20     percent_emails_from_poi       0.000        False

# %%
pca = PCA(n_components=scaled_train_features.shape[1])
pca = pca.fit(scaled_train_features)

pca_explained = pca.explained_variance_ratio_
pca_explained_df = pd.DataFrame({'n_components':range(1,len(pca_explained)+1), 'variance_explained':pca_explained})

print ggplot(aes(x = 'n_components', y = 'variance_explained'), data= pca_explained_df) +\
            geom_point() +\
            labs(title = 'Variance explained by number of n_components') +\
            geom_hline(y=.043)
# Out:
# <ggplot: (290681613)>

# %%
pca = PCA(n_components = 6)
pca = pca.fit(scaled_train_features)

# summarize components
print("Explained Variance: %s") % pca.explained_variance_ratio_

features_train_pca = pca.transform(scaled_train_features)
features_test_pca = pca.transform(scaled_test_features)
# Out:
# Explained Variance: [ 0.3265784   0.1447228   0.09251558  0.08411911  0.06022912  0.04413356]

# %%
df_filled = df.replace('NaN',0)
df_filled['email_address'] = df_filled['email_address'].replace(0, 'None')

feature_count = df_filled.shape[1]+1

print df_filled.corr().unstack().sort_values()[-feature_count-20:-feature_count]
# Out:
# restricted_stock         other                     0.634
# other                    restricted_stock          0.634
# bonus                    from_poi_to_this_person   0.642
# from_poi_to_this_person  bonus                     0.642
# bonus                    salary                    0.651
# salary                   bonus                     0.651
# total_stock_value        total_payments            0.662
# total_payments           total_stock_value         0.662
# bonus                    shared_receipt_with_poi   0.666
# shared_receipt_with_poi  bonus                     0.666
#                          from_poi_to_this_person   0.734
# from_poi_to_this_person  shared_receipt_with_poi   0.734
# total_stock_value        restricted_stock          0.781
# restricted_stock         total_stock_value         0.781
# other                    total_payments            0.830
# total_payments           other                     0.830
# shared_receipt_with_poi  to_messages               0.882
# to_messages              shared_receipt_with_poi   0.882
# director                 director_fees             0.905
# director_fees            director                  0.905
# dtype: float64

# %%
features_less_corr_train = features_train.drop(['director_fees','to_messages',
                                                'total_payments', 'total_stock_value'], axis =1)
features_less_corr_test = features_test.drop(['director_fees','to_messages',
                                                'total_payments', 'total_stock_value'], axis =1)

dt_lc_clf = DecisionTreeClassifier(random_state=1809)
dt_lc_clf.fit(features_less_corr_train, labels_train)
importance_lc_df = pd.DataFrame({'features':features_less_corr_train.columns,
                                 'importance':dt_lc_clf.feature_importances_})
dt_lc_important_features = importance_lc_df.sort_values('importance', ascending= False)['features'][0:6]
importance_lc_df.sort_values('importance', ascending= False)

scaled_lc_train_features = scale(features_less_corr_train)
lc_model = LogisticRegression()
lc_rfe = RFE(lc_model, 5)
lc_rfe.fit(scaled_lc_train_features, labels_train)

lc_rfe_selected = features_less_corr_train.columns[lc_rfe.support_]

importance_lc_df['lc_rfe_selected'] = lc_rfe.support_
importance_lc_df.sort_values('importance', ascending= False)
# Out:
#                       features  importance lc_rfe_selected
# 11             deferred_income       0.257            True
# 15  percent_from_emails_to_poi       0.220            True
# 8                from_messages       0.197           False
# 2      exercised_stock_options       0.084           False
# 3                        bonus       0.073            True
# 4             restricted_stock       0.066           False
# 7                     expenses       0.059           False
# 0                       salary       0.044           False
# 1            deferral_payments       0.000            True
# 9                        other       0.000           False
# 10     from_this_person_to_poi       0.000            True
# 6    restricted_stock_deferred       0.000           False
# 12         long_term_incentive       0.000           False
# 13     from_poi_to_this_person       0.000           False
# 14                    director       0.000           False
# 5      shared_receipt_with_poi       0.000           False
# 16     percent_emails_from_poi       0.000           False

# %%
scaler = StandardScaler().fit(features_less_corr_train)
scaled_less_corr_features_train = scaler.transform(features_less_corr_train)
scaled_less_corr_features_test = scaler.transform(features_less_corr_test)
scaled_less_corr_features_train = pd.DataFrame(scaled_less_corr_features_train,
                                               columns=features_less_corr_train.columns)
scaled_less_corr_features_test = pd.DataFrame(scaled_less_corr_features_test, 
                                              columns=features_less_corr_test.columns)

scaled_features_train = pd.DataFrame(scaled_features_train, columns=features_train.columns)
scaled_features_test = pd.DataFrame(scaled_features_test, columns=features_test.columns)

# %% [markdown]
# ### Pick and Tune an Algorithm
#
# We have some parameters to work with now so lets see how they perform with different Algorithms!

# %%
algos_tried = []

def add_results_to_dict(algo_name, data_used, pred, less_corr, scaled):
    algo_tried = {'algo': algo_name,
                  'data_used': data_used,
                  'accuracy' : accuracy_score(labels_test, pred),
                  'precision' : precision_score(labels_test, pred),
                  'recall': recall_score(labels_test, pred),
                  'less_corr': less_corr,
                  'scaled': scaled}
    algos_tried.append(algo_tried)

def test_all_datasets(classifier, algo, scaled = False):
    if scaled:
        train_features = scaled_features_train
        test_features = scaled_features_test
        train_less_corr = scaled_less_corr_features_train
        test_less_corr = scaled_less_corr_features_test
    else:
        train_features = features_train
        test_features = features_test
        train_less_corr = features_less_corr_train
        test_less_corr = features_less_corr_test
    classifier(train_features, features_test, algo, 'All', False) 
    classifier(train_less_corr, test_less_corr,
               algo, 'All Less Corr', True) 
    classifier(train_features[dt_important_features], 
                 features_test[dt_important_features],
                 algo, 'DT Important', False) 
    classifier(train_less_corr[dt_lc_important_features], 
                 test_less_corr[dt_lc_important_features],
                 algo, 'DT Important', True)
    classifier(train_features[rfe_selected], 
                 features_test[rfe_selected],
                 algo, 'RFE Selected', False)
    classifier(train_less_corr[lc_rfe_selected], 
                 test_less_corr[lc_rfe_selected],
                 algo, 'RFE Selected', True)
    classifier(features_train_pca, features_test_pca,
                 algo, 'PCA features', False)

# %%
def nb_classify(train_features, test_features, algo_name, data_used, less_corr):
    nb_clf = GaussianNB()
    nb_clf.fit(train_features, labels_train)
    nb_pred = nb_clf.predict(test_features)
    add_results_to_dict(algo_name, data_used, nb_pred, less_corr)

test_all_datasets(nb_classify, 'Naive Bayes')

# %%
def svm_classify(train_features, test_features, algo_name, data_used, less_corr):
    scaler = StandardScaler().fit(train_features)
    scaled_train_features = scaler.transform(train_features)
    scaled_test_features = scaler.transform(test_features)
    
    svm_clf = SVC()
    svm_clf.fit(scaled_train_features, labels_train)
    svm_pred = svm_clf.predict(scaled_test_features)
    add_results_to_dict(algo_name, data_used, svm_pred, less_corr)
    
test_all_datasets(svm_classify, 'SVM', True)

# %%
def ada_classify(train_features, test_features, algo_name, data_used, less_corr):
    ada_clf = AdaBoostClassifier()
    ada_clf.fit(train_features, labels_train)
    ada_pred = ada_clf.predict(test_features)
    add_results_to_dict(algo_name, data_used, ada_pred, less_corr)

test_all_datasets(ada_classify, 'AdaBoost')

# %%
pd.DataFrame.from_dict(algos_tried)
# Out:
#     accuracy         algo      data_used less_corr  precision  recall
# 0      0.622  Naive Bayes            All     False      0.263   1.000
# 1      0.649  Naive Bayes  All Less Corr      True      0.278   1.000
# 2      0.811  Naive Bayes   DT Important     False      0.333   0.400
# 3      0.865  Naive Bayes   DT Important      True      0.500   0.600
# 4      0.811  Naive Bayes   RFE Selected     False      0.375   0.600
# 5      0.811  Naive Bayes   RFE Selected      True      0.375   0.600
# 6      0.784  Naive Bayes   PCA features     False      0.286   0.400
# 7      0.865          SVM            All     False      0.000   0.000
# 8      0.865          SVM  All Less Corr      True      0.000   0.000
# 9      0.865          SVM   DT Important     False      0.000   0.000
# 10     0.865          SVM   DT Important      True      0.000   0.000
# 11     0.865          SVM   RFE Selected     False      0.000   0.000
# 12     0.865          SVM   RFE Selected      True      0.000   0.000
# 13     0.865          SVM   PCA features     False      0.000   0.000
# 14     0.865     AdaBoost            All     False      0.500   0.600
# 15     0.838     AdaBoost  All Less Corr      True      0.400   0.400
# 16     0.811     AdaBoost   DT Important     False      0.000   0.000
# 17     0.757     AdaBoost   DT Important      True      0.167   0.200
# 18     0.757     AdaBoost   RFE Selected     False      0.167   0.200
# 19     0.757     AdaBoost   RFE Selected      True      0.167   0.200
# 20     0.784     AdaBoost   PCA features     False      0.200   0.200

# %%
test_against
# Out:
#     accuracy         algo      data_used less_corr  precision  recall
# 0      0.622  Naive Bayes            All     False      0.263   1.000
# 1      0.649  Naive Bayes  All Less Corr      True      0.278   1.000
# 2      0.811  Naive Bayes   DT Important     False      0.333   0.400
# 3      0.865  Naive Bayes   DT Important      True      0.500   0.600
# 4      0.811  Naive Bayes   RFE Selected     False      0.375   0.600
# 5      0.811  Naive Bayes   RFE Selected      True      0.375   0.600
# 6      0.784  Naive Bayes   PCA features     False      0.286   0.400
# 7      0.865          SVM            All     False      0.000   0.000
# 8      0.865          SVM  All Less Corr      True      0.000   0.000
# 9      0.865          SVM   DT Important     False      0.000   0.000
# 10     0.865          SVM   DT Important      True      0.000   0.000
# 11     0.865          SVM   RFE Selected     False      0.000   0.000
# 12     0.865          SVM   RFE Selected      True      0.000   0.000
# 13     0.865          SVM   PCA features     False      0.000   0.000
# 14     0.865     AdaBoost            All     False      0.500   0.600
# 15     0.838     AdaBoost  All Less Corr      True      0.400   0.400
# 16     0.811     AdaBoost   DT Important     False      0.000   0.000
# 17     0.757     AdaBoost   DT Important      True      0.167   0.200
# 18     0.757     AdaBoost   RFE Selected     False      0.167   0.200
# 19     0.757     AdaBoost   RFE Selected      True      0.167   0.200
# 20     0.784     AdaBoost   PCA features     False      0.200   0.200
# 21     0.865          SVM            All     False      0.000   0.000
# 22     0.865          SVM  All Less Corr      True      0.000   0.000

# %%
features_less_corr_train = features_train.drop(['director_fees','to_messages',
                                                'total_payments', 'total_stock_value'], axis =1)
features_less_corr_test = features_test.drop(['director_fees','to_messages',
                                                'total_payments', 'total_stock_value'], axis =1)

dt_lc_clf = DecisionTreeClassifier(random_state=1809)
dt_lc_clf.fit(features_less_corr_train, labels_train)
importance_lc_df = pd.DataFrame({'features':features_less_corr_train.columns,
                                 'importance':dt_lc_clf.feature_importances_})
dt_lc_important_features = importance_lc_df.sort_values('importance', ascending= False)['features'][0:6]
importance_lc_df.sort_values('importance', ascending= False)

scaled_lc_train_features = scale(features_less_corr_train)
lc_model = LogisticRegression()
lc_rfe = RFE(lc_model, 5)
lc_rfe.fit(scaled_lc_train_features, labels_train)

lc_rfe_selected = features_less_corr_train.columns[lc_rfe.support_]

importance_lc_df['lc_rfe_selected'] = [x in lc_rfe_selected for x in importance_lc_df['features'].values]

importance_lc_df.sort_values('importance', ascending= False)
# Out:
#                       features  importance lc_rfe_selected
# 11             deferred_income       0.257            True
# 15  percent_from_emails_to_poi       0.220            True
# 8                from_messages       0.197           False
# 2      exercised_stock_options       0.084           False
# 3                        bonus       0.073            True
# 4             restricted_stock       0.066           False
# 7                     expenses       0.059           False
# 0                       salary       0.044           False
# 1            deferral_payments       0.000            True
# 9                        other       0.000           False
# 10     from_this_person_to_poi       0.000            True
# 6    restricted_stock_deferred       0.000           False
# 12         long_term_incentive       0.000           False
# 13     from_poi_to_this_person       0.000           False
# 14                    director       0.000           False
# 5      shared_receipt_with_poi       0.000           False
# 16     percent_emails_from_poi       0.000           False

# %%
features_less_corr_train.shape
# Out:
# (108, 17)

# %% [markdown]
# need to add scaling back for pca http://sebastianraschka.com/Articles/2014_about_feature_scaling.html#the-effect-of-standardization-on-pca-in-a-pattern-classification-task
